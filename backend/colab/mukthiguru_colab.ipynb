# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshodai/askmukthiguru-8119b0e8/blob/main/backend/colab/mukthiguru_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧘 Mukthi Guru — Colab Setup
#
# Run this notebook to deploy the full Mukthi Guru stack (RAG Backend + Ingestion UI) on Google Colab using a T4 GPU.

# %% [markdown]
# ### 1. Clone Repository
# We clone the repo and move into the backend directory.

# %%
# !git clone https://github.com/Harshodai/askmukthiguru-8119b0e8.git
# %cd askmukthiguru-8119b0e8/backend

# %% [markdown]
# ### 2. Install & Start Backend
# This script installs dependencies (Ollama, Qdrant, FastAPI), starts the server, and pulls the Llama 3 model.
#
# **Wait for "✅ Setup complete!"** before proceeding.

# %%
# !python colab/setup.py

# %% [markdown]
# ### 3. Expose to Public Internet
# Use your Ngrok token to create a tunnel to the backend.
#
# **Click the link** produced by this cell to access the UI.
# *(e.g. `https://...ngrok-free.app/ingest/`)*

# %%
from colab.setup import expose_with_ngrok

# REPLACE with your Ngrok Authtoken
NGROK_TOKEN = "39XAE9lDWUpvbwIsVEKYJA2CJmx_5osAm3dxGuc84znJxshYN"

expose_with_ngrok(NGROK_TOKEN)

# %% [markdown]
# ### 4. Data Persistence (Backup & Restore)
# Save your Qdrant vector data and downloaded models to Google Drive.

# %%
# Backup to Drive
# !python colab/transfer.py backup --models

# %%
# Restore from Drive (Example)
# !python colab/transfer.py restore /content/drive/MyDrive/MukthiGuru_Backups/mukthiguru_backup_YYYYMMDD.zip
